# %% [markdown]
# # X-CoT (Colab)

# %%
# Clone the X-CoT repo
# !git clone https://github.com/PrasannaPulakurthi/X-CoT.git
# %cd X-CoT

# %%
# Install dependencies
# !pip -q install --upgrade pip
# !pip install -r requirements.txt

# %%
#@title Configure inputs
dataset_name = "MSRVTT"  #@param ["MSRVTT", "DiDeMo", "LSMDC", "MSVD"]
top_k = 5 #@param {type:"number"}
init_retriever = "xpool"   #@param ["clip", "vlm2vec", "xpool"]

# %%
# Run X-CoT (Recommended: A100 GPU)
# !python xcot.py --exp_name={dataset_name} --dataset_name={dataset_name} --topk={top_k} --topk_retrieval_method={init_retriever} --sort_type="sliding_window"
